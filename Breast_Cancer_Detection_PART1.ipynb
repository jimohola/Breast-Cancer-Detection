# %%
#!pip install pyforest
from pyforest import*
lazy_imports()

# %matplotlib inline

# %%
data=pd.read_csv("Datasets/breastCancer.csv")
data.head()
# Out:
#         id  clump_thickness  size_uniformity  shape_uniformity  \
# 0  1000025                5                1                 1
# 1  1002945                5                4                 4
# 2  1015425                3                1                 1
# 3  1016277                6                8                 8
# 4  1017023                4                1                 1
#
#    marginal_adhesion  epithelial_size bare_nucleoli  bland_chromatin  \
# 0                  1                2             1                3
# 1                  5                7            10                3
# 2                  1                2             2                3
# 3                  1                3             4                3
# 4                  3                2             1                3
#
#    normal_nucleoli  mitoses  class
# 0                1        1      2
# 1                2        1      2
# 2                1        1      2
# ...

# %% [markdown]
# ## Data Pre-Processing

# %%
data['class'].value_counts()
# Out:
# 2    458
# 4    241
# Name: class, dtype: int64

# %%
data.shape
# Out:
# (699, 11)

# %%
data.dtypes #checking the data types of each column
# Out:
# id                    int64
# clump_thickness       int64
# size_uniformity       int64
# shape_uniformity      int64
# marginal_adhesion     int64
# epithelial_size       int64
# bare_nucleoli        object
# bland_chromatin       int64
# normal_nucleoli       int64
# mitoses               int64
# class                 int64
# dtype: object

# %% [markdown]
# #### let's inspect the "bare_nucleoli" column beacsue the data type depicts "Object".
# In Machine Learning all data types must be integer. The machine learning understand an integer. All data types has to be conveted to an integer before building the machine learning algorithm. So, there is somethhing preventing the column to present it as an interger.

# %%
data['bare_nucleoli'].head(30)
# Out:
# 0      1
# 1     10
# 2      2
# 3      4
# 4      1
# 5     10
# 6     10
# 7      1
# 8      1
# 9      1
# 10     1
# 11     1
# 12     3
# 13     3
# 14     9
# 15     1
# 16     1
# 17     1
# 18    10
# 19     1
# 20    10
# 21     7
# 22     1
# 23     ?
# 24     1
# 25     7
# 26     1
# 27     1
# 28     1
# 29     1
# Name: bare_nucleoli, dtype: object

# %% [markdown]
# ##### Note:
# There is a '?' at index 23. So now we check...

# %%
data[data['bare_nucleoli']=='?'] #checking the presence of '?' in the 'bare_nucleoli' column
# Out:
#           id  clump_thickness  size_uniformity  shape_uniformity  \
# 23   1057013                8                4                 5
# 40   1096800                6                6                 6
# 139  1183246                1                1                 1
# 145  1184840                1                1                 3
# 158  1193683                1                1                 2
# 164  1197510                5                1                 1
# 235  1241232                3                1                 4
# 249   169356                3                1                 1
# 275   432809                3                1                 3
# 292   563649                8                8                 8
# 294   606140                1                1                 1
# 297    61634                5                4                 3
# 315   704168                4                6                 5
# ...

# %% [markdown]
# ##### Alternartively
# Alternate means to check below....

# %%
data[data['bare_nucleoli']=='?'].sum() #
# Out:
# id                           13721250
# clump_thickness                    54
# size_uniformity                    39
# shape_uniformity                   46
# marginal_adhesion                  29
# epithelial_size                    39
# bare_nucleoli        ????????????????
# bland_chromatin                    50
# normal_nucleoli                    44
# mitoses                            16
# class                              36
# dtype: object

# %%
digits_in_bare_nucleoli= pd.DataFrame(data.bare_nucleoli.str.isdigit()).head(30) # Using the isdigit() function
digits_in_bare_nucleoli
# Out:
#     bare_nucleoli
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
# 5            True
# 6            True
# 7            True
# 8            True
# 9            True
# 10           True
# 11           True
# 12           True
# 13           True
# 14           True
# 15           True
# 16           True
# 17           True
# 18           True
# 19           True
# 20           True
# 21           True
# 22           True
# 23          False
# 24           True
# 25           True
# 26           True
# 27           True
# 28           True
# 29           True

# %% [markdown]
# ##### Replacing the missing values '?' with 'NAN' because it is recognisable by python and store in a new varibale DF

# %%
df= data.replace('?', np.nan)

# %%
df.bare_nucleoli.head(30)
# Out:
# 0       1
# 1      10
# 2       2
# 3       4
# 4       1
# 5      10
# 6      10
# 7       1
# 8       1
# 9       1
# 10      1
# 11      1
# 12      3
# 13      3
# 14      9
# 15      1
# 16      1
# 17      1
# 18     10
# 19      1
# 20     10
# 21      7
# 22      1
# 23    NaN
# 24      1
# 25      7
# 26      1
# 27      1
# 28      1
# 29      1
# Name: bare_nucleoli, dtype: object

# %% [markdown]
# ##### Repalcing the NAN with tte median so we will not be missing any information

# %%
df.median()
# Out:
# id                   1171710.0
# clump_thickness            4.0
# size_uniformity            1.0
# shape_uniformity           1.0
# marginal_adhesion          1.0
# epithelial_size            2.0
# bare_nucleoli              1.0
# bland_chromatin            3.0
# normal_nucleoli            1.0
# mitoses                    1.0
# class                      2.0
# dtype: float64

# %% [markdown]
# ##### The median for 'bare_nucleoli' is "1". So every NAN will be replace with 1

# %%
df = df.fillna(df.median())

# %%
df.bare_nucleoli.head(30) # index 23 is replaced with 1
# Out:
# 0       1
# 1      10
# 2       2
# 3       4
# 4       1
# 5      10
# 6      10
# 7       1
# 8       1
# 9       1
# 10      1
# 11      1
# 12      3
# 13      3
# 14      9
# 15      1
# 16      1
# 17      1
# 18     10
# 19      1
# 20     10
# 21      7
# 22      1
# 23    1.0
# 24      1
# 25      7
# 26      1
# 27      1
# 28      1
# 29      1
# Name: bare_nucleoli, dtype: object

# %%
df.dtypes
# Out:
# id                    int64
# clump_thickness       int64
# size_uniformity       int64
# shape_uniformity      int64
# marginal_adhesion     int64
# epithelial_size       int64
# bare_nucleoli        object
# bland_chromatin       int64
# normal_nucleoli       int64
# mitoses               int64
# class                 int64
# dtype: object

# %% [markdown]
# ##### The column is still 'Object'. So we will covert it using the "astype" function

# %%
df['bare_nucleoli'] = df['bare_nucleoli'].astype('int64')

# %%
df.dtypes
# Out:
# id                   int64
# clump_thickness      int64
# size_uniformity      int64
# shape_uniformity     int64
# marginal_adhesion    int64
# epithelial_size      int64
# bare_nucleoli        int64
# bland_chromatin      int64
# normal_nucleoli      int64
# mitoses              int64
# class                int64
# dtype: object

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.head()
# Out:
#         id  clump_thickness  size_uniformity  shape_uniformity  \
# 0  1000025                5                1                 1
# 1  1002945                5                4                 4
# 2  1015425                3                1                 1
# 3  1016277                6                8                 8
# 4  1017023                4                1                 1
#
#    marginal_adhesion  epithelial_size  bare_nucleoli  bland_chromatin  \
# 0                  1                2              1                3
# 1                  5                7             10                3
# 2                  1                2              2                3
# 3                  1                3              4                3
# 4                  3                2              1                3
#
#    normal_nucleoli  mitoses  class
# 0                1        1      2
# 1                2        1      2
# 2                1        1      2
# ...

# %%
# Dropping the index of the dataset because it is not needed

df.drop('id', axis=1, inplace=True)

# %%
df.head()
# Out:
#    clump_thickness  size_uniformity  shape_uniformity  marginal_adhesion  \
# 0                5                1                 1                  1
# 1                5                4                 4                  5
# 2                3                1                 1                  1
# 3                6                8                 8                  1
# 4                4                1                 1                  3
#
#    epithelial_size  bare_nucleoli  bland_chromatin  normal_nucleoli  mitoses  \
# 0                2              1                3                1        1
# 1                7             10                3                2        1
# 2                2              2                3                1        1
# 3                3              4                3                7        1
# 4                2              1                3                1        1
#
#    class
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2

# %%
df.describe().T
# Out:
#                    count      mean       std  min  25%  50%  75%   max
# clump_thickness    699.0  4.417740  2.815741  1.0  2.0  4.0  6.0  10.0
# size_uniformity    699.0  3.134478  3.051459  1.0  1.0  1.0  5.0  10.0
# shape_uniformity   699.0  3.207439  2.971913  1.0  1.0  1.0  5.0  10.0
# marginal_adhesion  699.0  2.806867  2.855379  1.0  1.0  1.0  4.0  10.0
# epithelial_size    699.0  3.216023  2.214300  1.0  2.0  2.0  4.0  10.0
# bare_nucleoli      699.0  3.486409  3.621929  1.0  1.0  1.0  5.0  10.0
# bland_chromatin    699.0  3.437768  2.438364  1.0  2.0  3.0  5.0  10.0
# normal_nucleoli    699.0  2.866953  3.053634  1.0  1.0  1.0  4.0  10.0
# mitoses            699.0  1.589413  1.715078  1.0  1.0  1.0  1.0  10.0
# class              699.0  2.689557  0.951273  2.0  2.0  2.0  4.0   4.0

# %% [markdown]
# #### Bivariate Data Analysis

# %%
# Plotting distribution of the class column 

sns.distplot(df['class'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='class', ylabel='Density'>

# %% [markdown]
# Each is evenly distributed and there are beningn than malignant

# %% [markdown]
# #### Multivariate Data Analysis

# %%
df.hist(bins=20, figsize=(30,30), layout=(6,3));

# %%
plt.figure(figsize= (15,10))
sns.boxplot(data=df,orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### Correlation among the varibales

# %%
df.corr()
# Out:
#                    clump_thickness  size_uniformity  shape_uniformity  \
# clump_thickness           1.000000         0.644913          0.654589
# size_uniformity           0.644913         1.000000          0.906882
# shape_uniformity          0.654589         0.906882          1.000000
# marginal_adhesion         0.486356         0.705582          0.683079
# epithelial_size           0.521816         0.751799          0.719668
# bare_nucleoli             0.590008         0.686673          0.707474
# bland_chromatin           0.558428         0.755721          0.735948
# normal_nucleoli           0.535835         0.722865          0.719446
# mitoses                   0.350034         0.458693          0.438911
# class                     0.716001         0.817904          0.818934
#
#                    marginal_adhesion  epithelial_size  bare_nucleoli  \
# clump_thickness             0.486356         0.521816       0.590008
# ...

# %%
# Heatmap of the correlation between the indepent attributes

plt.figure(figsize=(35,15))
sns.heatmap(df.corr(), vmax=1, square=True,annot=True,cmap='viridis')
plt.title('Correlation between different attributes')
plt.show()

# %%
# Pairplot of the correlation/distribution between various independent attributes

sns.pairplot(df, diag_kind="kde")

# %% [markdown]
# ##  Building the Model

# %%
df.head()
# Out:
#    clump_thickness  size_uniformity  shape_uniformity  marginal_adhesion  \
# 0                5                1                 1                  1
# 1                5                4                 4                  5
# 2                3                1                 1                  1
# 3                6                8                 8                  1
# 4                4                1                 1                  3
#
#    epithelial_size  bare_nucleoli  bland_chromatin  normal_nucleoli  mitoses  \
# 0                2              1                3                1        1
# 1                7             10                3                2        1
# 2                2              2                3                1        1
# 3                3              4                3                7        1
# 4                2              1                3                1        1
#
#    class
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2

# %%
# Dividing our dataset into training and testing set

X = df.drop('class', axis=1)  #selecting all the attributes except the class attribute
y = df['class'] #selecting class attribute.

# %%
# Splitting our data into 70:30
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %% [markdown]
# ### KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN = KNeighborsClassifier(n_neighbors= 5 , weights = 'distance' )

# %%
# Call Nearest Neighbour algorithm to lEARN from the training datasets

KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(weights='distance')

# %%
predicted_1 = KNN.predict(X_test)
predicted_1
# Out:
# array([2, 2, 2, 4, 2, 2, 4, 2, 2, 2, 4, 4, 2, 2, 4, 4, 2, 2, 2, 2, 2, 4,
#        4, 2, 4, 2, 4, 4, 2, 2, 2, 4, 4, 4, 4, 4, 2, 4, 2, 2, 2, 2, 2, 2,
#        2, 4, 2, 2, 2, 2, 2, 2, 4, 2, 4, 4, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 4, 2, 2, 2, 2, 2, 2, 4, 4, 2, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 4,
#        4, 2, 4, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4, 4, 2, 4, 2,
#        4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 2, 4, 2, 4, 2, 2, 2, 4,
#        4, 2, 4, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 4, 2, 4, 2, 2, 2, 2, 2, 4,
#        2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4, 4, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4,
#        4, 4, 4, 4, 4, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 4, 2, 4, 4, 4,
#        4, 2, 2, 2, 2, 2, 4, 4, 4, 2, 2, 2], dtype=int64)

# %%
from scipy.stats import zscore

print('KNeighborsClassifier Agorithm is predicting at {0:.2g}%'.format(KNN.score(X_test, y_test)*100))
# Out:
# KNeighborsClassifier Agorithm is predicting at 98%

# %% [markdown]
# ### Support Vector Machine

# %%
from sklearn.svm import SVC


svc= SVC(gamma=0.025, C=3)
svc.fit(X_train, y_train)
# Out:
# SVC(C=3, gamma=0.025)

# %%
predicted_2 = svc.predict(X_test)
predicted_2
# Out:
# array([2, 2, 2, 4, 2, 2, 4, 2, 2, 2, 4, 4, 2, 2, 4, 4, 2, 2, 2, 2, 2, 4,
#        4, 2, 4, 2, 4, 4, 2, 2, 2, 4, 4, 4, 4, 4, 2, 4, 2, 2, 2, 2, 2, 2,
#        2, 4, 2, 2, 2, 2, 2, 2, 4, 2, 4, 4, 4, 2, 2, 4, 2, 2, 2, 2, 2, 2,
#        2, 4, 2, 2, 2, 2, 2, 2, 4, 4, 2, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 4,
#        4, 2, 4, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 4, 4, 2, 2, 4, 4, 2, 4, 2,
#        4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 2, 4, 2, 4, 2, 2, 2, 4,
#        4, 2, 4, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 4, 2, 4, 2, 2, 2, 2, 2, 4,
#        2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4, 4, 2, 2, 2, 2, 2, 4, 4, 2, 2, 4,
#        4, 4, 4, 4, 4, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 4, 2, 4, 4, 4,
#        4, 2, 2, 2, 2, 2, 4, 4, 4, 2, 2, 2], dtype=int64)

# %%
print('SupportVectorClassifier Agorithm is predicting at {0:.2g}%'.format(svc.score(X_test, y_test)*100))
# Out:
# SupportVectorClassifier Agorithm is predicting at 98%

# %% [markdown]
# #### Comparison between the Models

# %% [markdown]
# knnPredictions=pd.DataFrame(predicted_1)
# svcPredictions=pd.DataFrame(predicted_2)

# %%
df1=pd.concat([knnPredictions,svcPredictions],axis=1)

# %%
df1.columns=[['knnPredictions','svcPredictions']]

# %%
df1
# Out:
#     knnPredictions svcPredictions
# 0                2              2
# 1                2              2
# 2                2              2
# 3                4              4
# 4                2              2
# ..             ...            ...
# 205              4              4
# 206              4              4
# 207              2              2
# 208              2              2
# 209              2              2
#
# [210 rows x 2 columns]

# %%
from sklearn.metrics import classification_report

print("classification_report for KNN")

print("..."*10)

print(classification_report(y_test, predicted_1))
# Out:
# classification_report for KNN
# ..............................
#               precision    recall  f1-score   support
#
#            2       0.97      0.99      0.98       137
#            4       0.99      0.95      0.97        73
#
#     accuracy                           0.98       210
#    macro avg       0.98      0.97      0.97       210
# weighted avg       0.98      0.98      0.98       210

# %%
from sklearn.metrics import classification_report

print("classification_report for SVC")

print("..."*10)

print(classification_report(y_test, predicted_2))
# Out:
# classification_report for SVC
# ..............................
#               precision    recall  f1-score   support
#
#            2       0.99      0.99      0.99       137
#            4       0.97      0.97      0.97        73
#
#     accuracy                           0.98       210
#    macro avg       0.98      0.98      0.98       210
# weighted avg       0.98      0.98      0.98       210

# %%
from sklearn import metrics

print("Confusion Matrix For KNeighborsClassifier")
cm=metrics.confusion_matrix(y_test, predicted_1, labels=[2, 4])

df_cm = pd.DataFrame(cm, index = [i for i in [2,4]],
                  columns = [i for i in ["Predict M","Predict B"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True)
# Out:
# Confusion Matrix For KNeighborsClassifier
# <AxesSubplot:>

# %%
print("Confusion Matrix For SupportVectorMachine")
cm=metrics.confusion_matrix(y_test, predicted_2, labels=[2, 4])

df_cm = pd.DataFrame(cm, index = [i for i in [2,4]],
                  columns = [i for i in ["Predict M","Predict B"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True)
# Out:
# Confusion Matrix For SupportVectorMachine
# <AxesSubplot:>
